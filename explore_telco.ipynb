# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Data getting, cleaning, and exploring
import wrangle as w
import explore as ex

# Python without these is hard
import pandas as pd
import numpy as np
from pydataset import data

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import graphviz
from graphviz import Graph

# %%
df = w.wrangle_telco()

# %%
df.head()
# Out:
#   customer_id  monthly_charges  tenure  total_charges
# 0  0003-MKNFE             59.9       9         542.40
# 1  0013-MHZWF             69.4       9         571.45
# 2  0015-UOCOJ             48.2       7         340.35
# 3  0023-HGHWL             25.1       1          25.10
# 4  0032-PGELS             30.5       1          30.50

# %%
df = df.set_index('customer_id')

# %%
df = ex.month_to_years(df)

# %%
train, validate, test = w.train_validate_test_split(df)

# %%
train.shape, validate.shape, test.shape
# Out:
# ((2170, 4), (930, 4), (775, 4))

# %%
train.head()
# Out:
#              monthly_charges  tenure  total_charges  tenure_years
# customer_id
# 5155-AZQPB             49.90      28        1410.25             2
# 5968-VXZLG             46.60       2          87.90             0
# 4529-CKBCL             80.20       2         146.05             0
# 7714-YXSMB            100.50      26        2599.95             2
# 5060-TQUQN             83.55      30        2570.20             2

# %%
sns.pairplot(train)

# %%
train.corr()
# Out:
#                  monthly_charges    tenure  total_charges  tenure_years
# monthly_charges         1.000000  0.355159       0.561528      0.337569
# tenure                  0.355159  1.000000       0.928137      0.981801
# total_charges           0.561528  0.928137       1.000000      0.916373
# tenure_years            0.337569  0.981801       0.916373      1.000000

# %%
sns.pairplot(train, kind='reg')
